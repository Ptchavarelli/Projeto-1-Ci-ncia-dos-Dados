# %% [markdown]
# Perguntas
#
# O IHD(indice de desenvolvimento humano) é um indice calculado por 3 fatores principais sendo eles:expectativa de vida,anos médios de estudos e renda per capita.Tendo em vista tal indice,é possivel que a densidade populacional de um país interfira em seu IDH?
#
# Países com um IDH maior tem necessariamente maior transparência internacional acerca da corrupção?

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt

# %%
#Leitura dos arquivos
IDH = pd.read_excel('Hdi.xlsx')
Corrupcao = pd.read_excel('Corrupcao.xlsx')
Population= pd.read_excel('Population.xlsx')

# %%
#Manter para um unico ano
IDh_2008 = IDH.loc[:, ["HDI", 2008]]
Corrupcao_2008 = Corrupcao.loc[:, ["Corrupcao", 2008]]
Population_2008 = Population.loc[:, ["Pop", '2008']]

# %%
#Mudança de indice
IDH_idx = IDh_2008.set_index('HDI')
corrup_idx = Corrupcao_2008.set_index('Corrupcao')
Population_idx = Population_2008.set_index('Pop')

# %%
#Renomear colunas
pt = IDH_idx.join(corrup_idx, how='inner', lsuffix='_IDH', rsuffix='_Corrupcao')
pt.head(173)
# Out:
#                           2008_IDH  2008_Corrupcao
# Afghanistan                  0.370             1.3
# Albania                      0.733             3.2
# Algeria                      0.686             2.8
# Angola                       0.476             1.9
# Argentina                    0.786             2.9
# Armenia                      0.719             2.7
# Australia                    0.924             8.7
# Austria                      0.876             7.9
# Azerbaijan                     NaN             2.3
# Bahrain                      0.806             5.1
# Bangladesh                   0.484             2.4
# Barbados                     0.792             7.4
# Belarus                      0.744             2.4
# Belgium                      0.882             7.1
# Benin                        0.419             2.9
# Bhutan                         NaN             5.0
# Bolivia                      0.651             2.7
# Bosnia and Herzegovina       0.730             3.0
# Botswana                     0.624             5.6
# Brazil                       0.705             3.7
# Brunei                       0.834             5.5
# Bulgaria                     0.765             3.8
# Burkina Faso                 0.321             3.6
# Burundi                      0.301             1.8
# Cambodia                     0.513             2.0
# Cameroon                     0.466             2.2
# Canada                       0.903             8.7
# Cape Verde                   0.563             5.1
# Central African Republic     0.327             2.0
# Chad                         0.316             1.6
# ...                            ...             ...
# Sudan                        0.399             1.5
# Suriname                     0.672             3.7
# Swaziland                    0.512             3.6
# Sweden                       0.900             9.2
# Switzerland                  0.892             9.0
# Syria                        0.629             2.6
# Taiwan                         NaN             5.6
# Tajikistan                   0.597             2.0
# Tanzania                     0.448             2.6
# Thailand                     0.672             3.4
# Timor-Leste                  0.505             2.2
# Togo                         0.426             2.8
# Tonga                        0.700             3.0
# Trinidad and Tobago          0.751             3.6
# Tunisia                      0.688             4.2
# Turkey                       0.691             4.4
# Turkmenistan                 0.671             1.8
# Uganda                       0.430             2.5
# Ukraine                      0.729             2.2
# United Arab Emirates         0.835             6.5
# United Kingdom               0.860             7.7
# United States                0.907             7.5
# Uruguay                      0.769             6.7
# Uzbekistan                   0.624             1.7
# Vanuatu                        NaN             3.2
# Venezuela                    0.730             1.9
# Vietnam                      0.580             2.7
# Yemen                        0.444             2.1
# Zambia                       0.413             3.0
# Zimbabwe                     0.338             2.2
#
# [173 rows x 2 columns]

# %%
#Adicionando a terceira coluna

Junto = pt.join(Population_idx, how="inner",)

# %%
##Shape do frame
Junto.shape
# Out:
# (165, 3)

# %%
#Junto.loc[['Afghanistan','Albania','Argentina','Armenia','Belarus','Bolivia','Bosnia and Herzegovina','Brazil','Bulgaria','Cambodia','Cameroon','Central African Republic','Chile','Colombia','Costa Rica','Croatia','Ecuador','Egypt','Hungary','Iraq','Malaysia','Mexico','Montenegro','Paraguay','Peru','Qatar','Romania','Russia','Serbia','Sri Lanka','Tajikistan','Tanzania','Thailand','Timor-Leste','Turkey','Ukraine','United States','Uruguay','New Zealand']].sort_values('2008_IDH')
Junto.dropna(axis=0,how='any',thresh=None,subset=None,inplace=True)
Junto.sort_values('2008_IDH').head(68)
# Out:
#                           2008_IDH  2008_Corrupcao      2008
# Congo, Dem. Rep.             0.270             1.9    26.643
# Niger                        0.282             2.9    11.405
# Burundi                      0.301             1.8   285.384
# Mozambique                   0.304             2.5    27.861
# Chad                         0.316             1.6     8.297
# Burkina Faso                 0.321             3.6    56.625
# Sierra Leone                 0.325             2.2    78.229
# Central African Republic     0.327             2.0     6.803
# Liberia                      0.328             3.1    32.850
# Zimbabwe                     0.338             2.2    31.865
# Guinea                       0.340             1.8    38.881
# Mali                         0.346             2.8    11.659
# Guinea-Bissau                0.346             1.9    40.242
# Ethiopia                     0.348             2.7    71.943
# Afghanistan                  0.370             1.3    45.761
# Malawi                       0.377             3.3   118.203
# Cote d'Ivoire                0.392             2.1    58.881
# Sudan                        0.399             1.5    16.528
# Gambia                       0.408             2.9   144.852
# Rwanda                       0.411             3.3   379.835
# Zambia                       0.413             3.0    16.449
# Benin                        0.419             2.9    74.195
# Djibouti                     0.421             2.8    36.881
# Togo                         0.426             2.8   101.732
# Comoros                      0.429             2.3   374.548
# Uganda                       0.430             2.5   130.018
# Lesotho                      0.436             3.3    70.084
# Nepal                        0.443             2.3   196.393
# Yemen                        0.444             2.1    42.856
# Haiti                        0.445             1.8   350.859
# ...                            ...             ...       ...
# Madagascar                   0.483             3.0    33.296
# Bangladesh                   0.484             2.4  1010.280
# Kenya                        0.493             2.2    66.261
# Pakistan                     0.495             2.4   210.329
# Sao Tome and Principe        0.496             2.8   165.822
# Timor-Leste                  0.505             2.2    72.593
# Swaziland                    0.512             3.6    66.249
# Cambodia                     0.513             2.0    76.353
# Solomon Islands              0.514             2.8    17.657
# Ghana                        0.519             3.9    97.530
# Congo, Rep.                  0.520             1.9    11.217
# India                        0.527             3.4   362.266
# Equatorial Guinea            0.537             1.8    23.612
# Cape Verde                   0.563             5.1   120.846
# Iraq                         0.564             1.5    68.036
# Guatemala                    0.568             3.4   125.732
# Morocco                      0.570             3.3    70.141
# Vietnam                      0.580             2.7   259.134
# Nicaragua                    0.583             2.5    43.351
# Tajikistan                   0.597             2.0    46.760
# Indonesia                    0.598             2.8   123.362
# South Africa                 0.608             4.7    40.391
# Namibia                      0.613             4.5     2.669
# Honduras                     0.619             2.5    65.152
# Guyana                       0.622             2.6     3.496
# Uzbekistan                   0.624             1.7    59.928
# Botswana                     0.624             5.6     3.360
# Syria                        0.629             2.6   106.352
# Egypt                        0.633             2.8    78.210
# Philippines                  0.635             2.4   300.577
#
# [68 rows x 3 columns]

# %%
plt.scatter(Junto['2008_IDH'],Junto['2008_Corrupcao'])
plt.xlabel('IDH')
plt.ylabel('Transparecia corrupcao')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.scatter(Junto['2008_IDH'],Junto['2008'])
plt.xlabel('IDH')
plt.ylabel('Pop den')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.scatter(Junto['2008_Corrupcao'],Junto['2008'])
plt.xlabel('Transparecia corrupcao')
plt.ylabel('Pop den')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
Junto.describe()
# Out:
#          2008_IDH  2008_Corrupcao         2008
# count  165.000000      165.000000   165.000000
# mean     0.649594        4.027879   207.767133
# std      0.179619        2.120705   745.490378
# min      0.270000        1.300000     1.703000
# 25%      0.495000        2.500000    29.759000
# 50%      0.688000        3.300000    70.084000
# 75%      0.792000        5.100000   130.018000
# max      0.941000        9.400000  6987.139000

# %%
#Salvar em arquivo csv
Junto.to_csv('Dataframe.csv', sep='\t', encoding='utf-8',index=True)
